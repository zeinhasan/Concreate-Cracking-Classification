# %% [markdown]
# # Library

# %%
import cv2
import os
import numpy as np
from sklearn import svm
from skimage import exposure, feature
from imutils import paths
import matplotlib.pyplot as plt
import argparse
from sklearn.metrics import confusion_matrix, classification_report, f1_score, accuracy_score, log_loss
import seaborn as sns
import pandas as pd
import random
import shutil

# %% [markdown]
# # Local Binary Pattern (Numpoints=120, radius 2)

# %%
# Local Binnary Patterns (LBP) class
class LocalBinaryPatterns:
    def __init__(self, numPoints, radius):
        self.numPoints = numPoints
        self.radius = radius

    def describe(self, image, eps=1e-7):
        lbp = feature.local_binary_pattern(image, self.numPoints,
                                           self.radius, method="uniform")
        (hist, _) = np.histogram(lbp.ravel(),
                                  bins=np.arange(0, self.numPoints + 3),
                                  range=(0, self.numPoints + 2))

        # Normalize the histogram
        hist = hist.astype("float")
        hist /= (hist.sum() + eps)

        return hist

# %%
# Initialize the local binary patterns descriptor along with
desc = LocalBinaryPatterns(120, 2)

# %%
# Specify the paths to the training and testing images
training_path = "Dataset/Train"
testing_path = "Dataset/Test"

# %%
# Initialize the data and label lists
data = []
labels = []

# Loop over the training images
for imagePath in paths.list_images(training_path):
    # Load the image, convert it to grayscale, and describe it
    image = cv2.imread(imagePath)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    hist = desc.describe(gray)

    # Extract the label from the image path, then update the
    # label and data lists
    labels.append(imagePath.split(os.path.sep)[-2])
    data.append(hist)

# %%
# Check the length of the data and labels
print('Length of the data:', len(data))
print('Length of the labels:', len(labels))

# Check the label names
print('Label names:', np.unique(labels))

# Check the shape of the data
print('Shape of the data:', np.shape(data))

# Check the data each label
print('Number of positive images:', labels.count('Positive'))
print('Number of negative images:', labels.count('Negative'))
# Out:
# Length of the data: 32000
# Length of the labels: 32000
# Label names: ['Negative' 'Positive']
# Shape of the data: (32000, 122)
# Number of positive images: 16000
# Number of negative images: 16000

# %% [markdown]
# # Training Model Linear SVM

# %%
# Train a Linear SVM on the data
model_svml = svm.SVC(kernel='linear', probability=True, random_state=42)
model_svml.fit(data, labels)
# Out:
# SVC(kernel='linear', probability=True, random_state=42)

# %% [markdown]
# # Training Model RBF SVM

# %%
# Train a RBF SVM on the data
model_svmr = svm.SVC(kernel='rbf', probability=True, random_state=42)
model_svmr.fit(data, labels)
# Out:
# SVC(probability=True, random_state=42)

# %% [markdown]
# # Training Model Poly SVM

# %%
# Train a Polynomial SVM on the data
model_svmp = svm.SVC(kernel='poly', probability=True, random_state=42)
model_svmp.fit(data, labels)
# Out:
# SVC(kernel='poly', probability=True, random_state=42)

# %% [markdown]
# # Training Model Sigmoid SVM

# %%
# Train a Sigmoid SVM on the data
model_svms = svm.SVC(kernel='sigmoid', probability=True, random_state=42)
model_svms.fit(data, labels)
# Out:
# SVC(kernel='sigmoid', probability=True, random_state=42)

# %% [markdown]
# # Confussion Matrix & Classification Report Linear SVM

# %%
# Initialize empty lists for true labels and predicted labels
true_labels = []
predicted_labels = []

# Loop over the testing images
for imagePath in paths.list_images(testing_path):
    # Load the image, convert it to grayscale, describe it,
    # and classify it
    image = cv2.imread(imagePath)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    hist = desc.describe(gray)
    prediction = model_svml.predict(hist.reshape(1, -1))

    # Extract the true label from the image path
    true_label = imagePath.split(os.path.sep)[-2]

    # Update the lists
    true_labels.append(true_label)
    predicted_labels.append(prediction[0])

# Create the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Display the confusion matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=np.unique(true_labels),
            yticklabels=np.unique(true_labels))
plt.title('Confusion Matrix Linear SVM')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
# Get the classification report
class_report = classification_report(true_labels, predicted_labels, digits=4)
print("Classification Report:\n", class_report)

# Get the accuracy score
acc_score_svml_n120r2 = accuracy_score(true_labels, predicted_labels)
print("Accuracy Score:", acc_score_svml_n120r2)

# Get the F1 score
f1_score_svml_n120r2 = f1_score(true_labels, predicted_labels, average='weighted')
print("F1 Score:", f1_score_svml_n120r2)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#     Negative     0.7262    0.8367    0.7776      4000
#     Positive     0.8074    0.6845    0.7409      4000
#
#     accuracy                         0.7606      8000
#    macro avg     0.7668    0.7606    0.7592      8000
# weighted avg     0.7668    0.7606    0.7592      8000
#
# Accuracy Score: 0.760625
# F1 Score: 0.7592297325380224

# %% [markdown]
# # Confussion Matrix & Classification Report RBF SVM

# %%
# Initialize empty lists for true labels and predicted labels
true_labels = []
predicted_labels = []

# Loop over the testing images
for imagePath in paths.list_images(testing_path):
    # Load the image, convert it to grayscale, describe it,
    # and classify it
    image = cv2.imread(imagePath)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    hist = desc.describe(gray)
    prediction = model_svmr.predict(hist.reshape(1, -1))

    # Extract the true label from the image path
    true_label = imagePath.split(os.path.sep)[-2]

    # Update the lists
    true_labels.append(true_label)
    predicted_labels.append(prediction[0])

# Create the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Display the confusion matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=np.unique(true_labels),
            yticklabels=np.unique(true_labels))
plt.title('Confusion Matrix RBF SVM')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
# Get the classification report
class_report = classification_report(true_labels, predicted_labels, digits=4)
print("Classification Report:\n", class_report)

# Get the accuracy score
acc_score_svmr_n120r2 = accuracy_score(true_labels, predicted_labels)
print("Accuracy Score:", acc_score_svmr_n120r2)

# Get the F1 score
f1_score_svmr_n120r2 = f1_score(true_labels, predicted_labels, average='weighted')
print("F1 Score:", f1_score_svmr_n120r2)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#     Negative     0.8919    0.9473    0.9188      4000
#     Positive     0.9438    0.8852    0.9136      4000
#
#     accuracy                         0.9163      8000
#    macro avg     0.9179    0.9163    0.9162      8000
# weighted avg     0.9179    0.9163    0.9162      8000
#
# Accuracy Score: 0.91625
# F1 Score: 0.9161694388307163

# %% [markdown]
# # Confussion Matrix & Classification Report Poly SVM

# %%
# Initialize empty lists for true labels and predicted labels
true_labels = []
predicted_labels = []

# Loop over the testing images
for imagePath in paths.list_images(testing_path):
    # Load the image, convert it to grayscale, describe it,
    # and classify it
    image = cv2.imread(imagePath)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    hist = desc.describe(gray)
    prediction = model_svmp.predict(hist.reshape(1, -1))

    # Extract the true label from the image path
    true_label = imagePath.split(os.path.sep)[-2]

    # Update the lists
    true_labels.append(true_label)
    predicted_labels.append(prediction[0])

# Create the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Display the confusion matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=np.unique(true_labels),
            yticklabels=np.unique(true_labels))
plt.title('Confusion Matrix Poly SVM')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
# Get the classification report
class_report = classification_report(true_labels, predicted_labels, digits=4)
print("Classification Report:\n", class_report)

# Get the accuracy score
acc_score_svmp_n120r2 = accuracy_score(true_labels, predicted_labels)
print("Accuracy Score:", acc_score_svmp_n120r2)

# Get the F1 score
f1_score_svmp_n120r2 = f1_score(true_labels, predicted_labels, average='weighted')
print("F1 Score:", f1_score_svmp_n120r2)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#     Negative     0.9009    0.9545    0.9269      4000
#     Positive     0.9516    0.8950    0.9224      4000
#
#     accuracy                         0.9247      8000
#    macro avg     0.9263    0.9247    0.9247      8000
# weighted avg     0.9263    0.9247    0.9247      8000
#
# Accuracy Score: 0.92475
# F1 Score: 0.9246833400486518

# %% [markdown]
# # Confussion Matrix & Classification Report Sigmoid SVM

# %%
# Initialize empty lists for true labels and predicted labels
true_labels = []
predicted_labels = []

# Loop over the testing images
for imagePath in paths.list_images(testing_path):
    # Load the image, convert it to grayscale, describe it,
    # and classify it
    image = cv2.imread(imagePath)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    hist = desc.describe(gray)
    prediction = model_svms.predict(hist.reshape(1, -1))

    # Extract the true label from the image path
    true_label = imagePath.split(os.path.sep)[-2]

    # Update the lists
    true_labels.append(true_label)
    predicted_labels.append(prediction[0])

# Create the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Display the confusion matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=np.unique(true_labels),
            yticklabels=np.unique(true_labels))
plt.title('Confusion Matrix Sigmoid SVM')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %%
# Get the classification report
class_report = classification_report(true_labels, predicted_labels, digits=4)
print("Classification Report:\n", class_report)

# Get the accuracy score
acc_score_svms_n120r2 = accuracy_score(true_labels, predicted_labels)
print("Accuracy Score:", acc_score_svms_n120r2)

# Get the F1 score
f1_score_svms_n120r2 = f1_score(true_labels, predicted_labels, average='weighted')
print("F1 Score:", f1_score_svms_n120r2)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#     Negative     0.5337    0.5717    0.5521      4000
#     Positive     0.5389    0.5005    0.5190      4000
#
#     accuracy                         0.5361      8000
#    macro avg     0.5363    0.5361    0.5355      8000
# weighted avg     0.5363    0.5361    0.5355      8000
#
# Accuracy Score: 0.536125
# F1 Score: 0.5355355292713291

# %% [markdown]
# # Wrap Up

# %%
# wrap the models in a list
# make dict of models to loop through
model = {
    "Linear SVM NumPoint = 120 Radius = 2": model_svml,
    "RBF SVM NumPoint = 120 Radius = 2": model_svmr,
    "Polynomial SVM NumPoint = 120 Radius = 2": model_svmp,
    "Sigmoid SVM NumPoint = 120 Radius = 2": model_svms
}

# Make dict of accuracy scores to loop through
acc_score = {
    "Linear SVM NumPoint = 120 Radius = 2": acc_score_svml_n120r2,
    "RBF SVM NumPoint = 120 Radius = 2": acc_score_svmr_n120r2,
    "Polynomial NumPoint = 120 Radius = 2": acc_score_svmp_n120r2,
    "Sigmoid SVM NumPoint = 120 Radius = 2": acc_score_svms_n120r2
}

# Make dict of F1 scores to loop through
f1_score = {
    "Linear SVM NumPoint = 120 Radius = 2": f1_score_svml_n120r2,
    "RBF SVM NumPoint = 120 Radius = 2": f1_score_svmr_n120r2,
    "Polynomial SVM NumPoint = 120 Radius = 2": f1_score_svmp_n120r2,
    "Sigmoid SVM NumPoint = 120 Radius = 2": f1_score_svms_n120r2
}

# Make DataFrame of all the scores
df = pd.DataFrame(list(acc_score.items()), columns=['Model', 'Accuracy Score'])
df['F1 Score'] = f1_score.values()

# Sort the values by f1 score
df.sort_values(by=['F1 Score'], inplace=True, ascending=False)

# Display the DataFrame
print(df)
# Out:
#                                    Model  Accuracy Score  F1 Score
# 2   Polynomial NumPoint = 120 Radius = 2        0.924750  0.924683
# 1      RBF SVM NumPoint = 120 Radius = 2        0.916250  0.916169
# 0   Linear SVM NumPoint = 120 Radius = 2        0.760625  0.759230
# 3  Sigmoid SVM NumPoint = 120 Radius = 2        0.536125  0.535536

# %%
# Save all the model
import pickle
# model as a pickle file
model_svml_pkl_file = "svml_n120r2.pkl"
model_svmr_pkl_file = "svmr_n120r2.pkl"
model_svmp_pkl_file = "svmp_n120r2.pkl"
model_svms_pkl_file = "svms_n120r2.pkl"

with open(model_svml_pkl_file, 'wb') as file:  
    pickle.dump(model_svml, file)

with open(model_svmr_pkl_file, 'wb') as file:
    pickle.dump(model_svmr, file)

with open(model_svmp_pkl_file, 'wb') as file:
    pickle.dump(model_svmp, file)

with open(model_svms_pkl_file, 'wb') as file:
    pickle.dump(model_svms, file)
