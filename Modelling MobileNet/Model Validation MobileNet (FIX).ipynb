# %% [markdown]
# # Library

# %%
# Import the necessary packages and modules
import numpy as np
import os
# Surpress Warnings
import warnings
warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
# library visualization
import matplotlib.pyplot as plt

# Library Tensorflow
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.applications.mobilenet import MobileNet

# Others
import shutil
import random
import pandas as pd

# Confusion Matrix and Classification Report
from sklearn.metrics import confusion_matrix, classification_report
from mlxtend.plotting import plot_confusion_matrix
from sklearn.metrics import f1_score

# %% [markdown]
# # Load dataset

# %%
# All images will be rescaled by 1./255.
val_datagen = ImageDataGenerator(rescale=1./255)

# Flow training images in batches of 20 using train_datagen generator
val_generator = val_datagen.flow_from_directory(
        "Dataset/Test",  # This is the source directory for training images
        target_size=(224, 224),  # All images will be resized to 224x224
        # Specify the classes explicitly
        classes = ['Negative', 'Positive'],
        # Since we use categorical_crossentropy loss, we need categorical labels
        class_mode='categorical',
        shuffle=False)
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# # Load all model

# %%
# Load Model
MobileNet_basic=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Basic.h5', compile=False)
MobileNet_Modified099=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified099.h5', compile=False)
MobileNet_Modified098=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified098.h5', compile=False)
MobileNet_Modified097=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified097.h5', compile=False)
MobileNet_Modified096=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified096.h5', compile=False)
MobileNet_Modified095=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified095.h5', compile=False)
MobileNet_Modified094=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified094.h5', compile=False)
MobileNet_Modified093=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified093.h5', compile=False)
MobileNet_Modified092=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified092.h5', compile=False)
MobileNet_Modified091=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified091.h5', compile=False)
MobileNet_Modified090=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified090.h5', compile=False)
MobileNet_Modified089=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified089.h5', compile=False)
MobileNet_Modified088=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified088.h5', compile=False)
MobileNet_Modified087=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified087.h5', compile=False)
MobileNet_Modified086=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified086.h5', compile=False)
MobileNet_Modified085=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified085.h5', compile=False)
MobileNet_Modified084=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified084.h5', compile=False)
MobileNet_Modified083=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified083.h5', compile=False)
MobileNet_Modified082=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified082.h5', compile=False)
MobileNet_Modified081=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified081.h5', compile=False)
MobileNet_Modified080=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified080.h5', compile=False)
MobileNet_Modified079=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified079.h5', compile=False)
MobileNet_Modified078=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified078.h5', compile=False)
MobileNet_Modified077=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified077.h5', compile=False)
MobileNet_Modified076=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified076.h5', compile=False)
MobileNet_Modified075=keras.models.load_model('Modelling MobileNet/Model MobileNet/MobileNet_Modified075.h5', compile=False)

# %%
# Compile Model
MobileNet_basic.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified099.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified098.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified097.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified096.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified095.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified094.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified093.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified092.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified091.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified090.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified089.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified088.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified087.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified086.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified085.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified084.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified083.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified082.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified081.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified080.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified079.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified078.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified077.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified076.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
MobileNet_Modified075.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# # MobileNet Basic Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Basic = MobileNet_basic.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Basic[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Basic[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 11s 29ms/step - loss: 0.0111 - accuracy: 0.9979
# Accuracy: 99.787498%
# Loss: 1.110823%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_basic.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet Basic Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_basic = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_basic)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 9s 33ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9987    0.9970    0.9979      4000
#     Positive     0.9970    0.9988    0.9979      4000
#
#     accuracy                         0.9979      8000
#    macro avg     0.9979    0.9979    0.9979      8000
# weighted avg     0.9979    0.9979    0.9979      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9978749983730456

# %% [markdown]
# # MobileNet Modified099 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified099 = MobileNet_Modified099.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified099[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified099[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 9s 32ms/step - loss: 0.0091 - accuracy: 0.9980
# Accuracy: 99.800003%
# Loss: 0.911801%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified099.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.99) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified099 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified099)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 8s 30ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9987    0.9972    0.9980      4000
#     Positive     0.9973    0.9988    0.9980      4000
#
#     accuracy                         0.9980      8000
#    macro avg     0.9980    0.9980    0.9980      8000
# weighted avg     0.9980    0.9980    0.9980      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9979999988749994

# %% [markdown]
# # MobileNet Modified098 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified098 = MobileNet_Modified098.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified098[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified098[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 9s 31ms/step - loss: 0.0082 - accuracy: 0.9981
# Accuracy: 99.812502%
# Loss: 0.821669%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified098.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.98) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified098 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified098)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 7s 28ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9992    0.9970    0.9981      4000
#     Positive     0.9970    0.9992    0.9981      4000
#
#     accuracy                         0.9981      8000
#    macro avg     0.9981    0.9981    0.9981      8000
# weighted avg     0.9981    0.9981    0.9981      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9981249976269501

# %% [markdown]
# # MobileNet Modified097 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified097 = MobileNet_Modified097.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified097[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified097[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 8s 29ms/step - loss: 0.0137 - accuracy: 0.9965
# Accuracy: 99.650002%
# Loss: 1.372247%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified097.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.97) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified097 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified097)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 8s 30ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9987    0.9942    0.9965      4000
#     Positive     0.9943    0.9988    0.9965      4000
#
#     accuracy                         0.9965      8000
#    macro avg     0.9965    0.9965    0.9965      8000
# weighted avg     0.9965    0.9965    0.9965      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9964999822811603

# %% [markdown]
# # MobileNet Modified096 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified096 = MobileNet_Modified096.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified096[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified096[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 8s 30ms/step - loss: 0.0077 - accuracy: 0.9985
# Accuracy: 99.849999%
# Loss: 0.766986%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified096.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.96) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified096 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified096)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 8s 32ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9987    0.9982    0.9985      4000
#     Positive     0.9983    0.9988    0.9985      4000
#
#     accuracy                         0.9985      8000
#    macro avg     0.9985    0.9985    0.9985      8000
# weighted avg     0.9985    0.9985    0.9985      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9984999999062499

# %% [markdown]
# # MobileNet Modified095 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified095 = MobileNet_Modified095.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified095[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified095[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 9s 33ms/step - loss: 0.0078 - accuracy: 0.9986
# Accuracy: 99.862498%
# Loss: 0.776298%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified095.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.95) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified095 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified095)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 10s 39ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9985    0.9988    0.9986      4000
#     Positive     0.9987    0.9985    0.9986      4000
#
#     accuracy                         0.9986      8000
#    macro avg     0.9986    0.9986    0.9986      8000
# weighted avg     0.9986    0.9986    0.9986      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9986249999785157

# %% [markdown]
# # MobileNet Modified094 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified094 = MobileNet_Modified094.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified094[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified094[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 9s 33ms/step - loss: 0.0135 - accuracy: 0.9971
# Accuracy: 99.712503%
# Loss: 1.346496%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified094.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.94) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified094 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified094)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 8s 30ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9990    0.9952    0.9971      4000
#     Positive     0.9953    0.9990    0.9971      4000
#
#     accuracy                         0.9971      8000
#    macro avg     0.9971    0.9971    0.9971      8000
# weighted avg     0.9971    0.9971    0.9971      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9971249898925425

# %% [markdown]
# # MobileNet Modified093 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified093 = MobileNet_Modified093.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified093[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified093[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 9s 32ms/step - loss: 0.0087 - accuracy: 0.9986
# Accuracy: 99.862498%
# Loss: 0.866854%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified093.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.93) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified093 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified093)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 8s 31ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9983    0.9990    0.9986      4000
#     Positive     0.9990    0.9982    0.9986      4000
#
#     accuracy                         0.9986      8000
#    macro avg     0.9986    0.9986    0.9986      8000
# weighted avg     0.9986    0.9986    0.9986      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9986249998066407

# %% [markdown]
# # MobileNet Modified092 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified092 = MobileNet_Modified092.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified092[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified092[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 8s 30ms/step - loss: 0.0129 - accuracy: 0.9975
# Accuracy: 99.750000%
# Loss: 1.287435%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified092.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.92) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified092 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified092)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 9s 33ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9992    0.9958    0.9975      4000
#     Positive     0.9958    0.9992    0.9975      4000
#
#     accuracy                         0.9975      8000
#    macro avg     0.9975    0.9975    0.9975      8000
# weighted avg     0.9975    0.9975    0.9975      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9974999923437264

# %% [markdown]
# # MobileNet Modified091 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified091 = MobileNet_Modified091.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified091[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified091[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 10s 36ms/step - loss: 0.0097 - accuracy: 0.9984
# Accuracy: 99.837500%
# Loss: 0.972575%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified091.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.91) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified091 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified091)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 9s 35ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9995    0.9972    0.9984      4000
#     Positive     0.9973    0.9995    0.9984      4000
#
#     accuracy                         0.9984      8000
#    macro avg     0.9984    0.9984    0.9984      8000
# weighted avg     0.9984    0.9984    0.9984      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9983749979433568

# %% [markdown]
# # MobileNet Modified090 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified090 = MobileNet_Modified090.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified090[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified090[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 10s 35ms/step - loss: 0.0122 - accuracy: 0.9980
# Accuracy: 99.800003%
# Loss: 1.223370%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified090.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.90) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified090 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified090)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 9s 35ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9992    0.9968    0.9980      4000
#     Positive     0.9968    0.9992    0.9980      4000
#
#     accuracy                         0.9980      8000
#    macro avg     0.9980    0.9980    0.9980      8000
# weighted avg     0.9980    0.9980    0.9980      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9979999968749951

# %% [markdown]
# # MobileNet Modified089 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified089 = MobileNet_Modified089.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified089[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified089[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 9s 32ms/step - loss: 0.0170 - accuracy: 0.9974
# Accuracy: 99.737501%
# Loss: 1.701082%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified089.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.89) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified089 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified089)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 8s 31ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9992    0.9955    0.9974      4000
#     Positive     0.9955    0.9992    0.9974      4000
#
#     accuracy                         0.9974      8000
#    macro avg     0.9974    0.9974    0.9974      8000
# weighted avg     0.9974    0.9974    0.9974      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9973749907714519

# %% [markdown]
# # MobileNet Modified088 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified088 = MobileNet_Modified088.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified088[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified088[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 8s 30ms/step - loss: 0.0094 - accuracy: 0.9983
# Accuracy: 99.825001%
# Loss: 0.939501%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified088.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.94) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified088 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified088)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 9s 33ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9987    0.9978    0.9982      4000
#     Positive     0.9978    0.9988    0.9983      4000
#
#     accuracy                         0.9982      8000
#    macro avg     0.9983    0.9983    0.9982      8000
# weighted avg     0.9983    0.9982    0.9982      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9982499995624998

# %% [markdown]
# # MobileNet Modified087 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified087 = MobileNet_Modified087.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified087[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified087[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 8s 29ms/step - loss: 0.0083 - accuracy: 0.9981
# Accuracy: 99.812502%
# Loss: 0.826804%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified087.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.87) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified087 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified087)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 8s 32ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9992    0.9970    0.9981      4000
#     Positive     0.9970    0.9992    0.9981      4000
#
#     accuracy                         0.9981      8000
#    macro avg     0.9981    0.9981    0.9981      8000
# weighted avg     0.9981    0.9981    0.9981      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9981249976269501

# %% [markdown]
# # MobileNet Modified086 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified086 = MobileNet_Modified086.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified086[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified086[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 9s 31ms/step - loss: 0.0210 - accuracy: 0.9967
# Accuracy: 99.675000%
# Loss: 2.102306%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified086.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.86) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified086 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified086)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 7s 28ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9987    0.9948    0.9967      4000
#     Positive     0.9948    0.9988    0.9968      4000
#
#     accuracy                         0.9968      8000
#    macro avg     0.9968    0.9968    0.9967      8000
# weighted avg     0.9968    0.9968    0.9967      8000
#
# ==========================F1 Score====================
# F1 Score :  0.996749986999948

# %% [markdown]
# # MobileNet Modified085 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified085 = MobileNet_Modified085.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified085[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified085[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 9s 29ms/step - loss: 0.0084 - accuracy: 0.9984
# Accuracy: 99.837500%
# Loss: 0.835780%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified085.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.85) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified085 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified085)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 9s 33ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9990    0.9978    0.9984      4000
#     Positive     0.9978    0.9990    0.9984      4000
#
#     accuracy                         0.9984      8000
#    macro avg     0.9984    0.9984    0.9984      8000
# weighted avg     0.9984    0.9984    0.9984      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9983749993652341

# %% [markdown]
# # MobileNet Modified084 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified084 = MobileNet_Modified084.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified084[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified084[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 8s 30ms/step - loss: 0.0086 - accuracy: 0.9984
# Accuracy: 99.837500%
# Loss: 0.858542%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified084.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.84) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified084 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified084)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 9s 33ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9985    0.9982    0.9984      4000
#     Positive     0.9983    0.9985    0.9984      4000
#
#     accuracy                         0.9984      8000
#    macro avg     0.9984    0.9984    0.9984      8000
# weighted avg     0.9984    0.9984    0.9984      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9983749999746094

# %% [markdown]
# # MobileNet Modified083 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified083 = MobileNet_Modified083.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified083[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified083[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 8s 29ms/step - loss: 0.0044 - accuracy: 0.9987
# Accuracy: 99.874997%
# Loss: 0.438801%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified083.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.83) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified083 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified083)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 9s 33ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9997    0.9978    0.9987      4000
#     Positive     0.9978    0.9998    0.9988      4000
#
#     accuracy                         0.9988      8000
#    macro avg     0.9988    0.9988    0.9987      8000
# weighted avg     0.9988    0.9988    0.9987      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9987499987499988

# %% [markdown]
# # MobileNet Modified082 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified082 = MobileNet_Modified082.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified082[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified082[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 9s 31ms/step - loss: 0.0159 - accuracy: 0.9973
# Accuracy: 99.725002%
# Loss: 1.585411%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified082.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.82) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified082 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified082)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 8s 32ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9992    0.9952    0.9972      4000
#     Positive     0.9953    0.9992    0.9973      4000
#
#     accuracy                         0.9972      8000
#    macro avg     0.9973    0.9972    0.9972      8000
# weighted avg     0.9973    0.9972    0.9972      8000
#
# ==========================F1 Score====================
# F1 Score :  0.997249988999956

# %% [markdown]
# # MobileNet Modified081 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified081 = MobileNet_Modified081.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified081[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified081[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 8s 29ms/step - loss: 0.0122 - accuracy: 0.9979
# Accuracy: 99.787498%
# Loss: 1.222021%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified081.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.81) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified081 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified081)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 8s 29ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9992    0.9965    0.9979      4000
#     Positive     0.9965    0.9992    0.9979      4000
#
#     accuracy                         0.9979      8000
#    macro avg     0.9979    0.9979    0.9979      8000
# weighted avg     0.9979    0.9979    0.9979      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9978749959824142

# %% [markdown]
# # MobileNet Modified080 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified080 = MobileNet_Modified080.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified080[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified080[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 8s 30ms/step - loss: 0.0093 - accuracy: 0.9985
# Accuracy: 99.849999%
# Loss: 0.932089%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified080.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.80) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified080 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified080)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 8s 30ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9990    0.9980    0.9985      4000
#     Positive     0.9980    0.9990    0.9985      4000
#
#     accuracy                         0.9985      8000
#    macro avg     0.9985    0.9985    0.9985      8000
# weighted avg     0.9985    0.9985    0.9985      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9984999996249999

# %% [markdown]
# # MobileNet Modified079 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified079 = MobileNet_Modified079.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified079[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified079[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 8s 28ms/step - loss: 0.0681 - accuracy: 0.9868
# Accuracy: 98.675001%
# Loss: 6.809866%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified079.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.79) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified079 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified079)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 9s 33ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9992    0.9742    0.9866      4000
#     Positive     0.9749    0.9992    0.9869      4000
#
#     accuracy                         0.9868      8000
#    macro avg     0.9871    0.9868    0.9867      8000
# weighted avg     0.9871    0.9868    0.9867      8000
#
# ==========================F1 Score====================
# F1 Score :  0.986747929363963

# %% [markdown]
# # MobileNet Modified078 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified078 = MobileNet_Modified078.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified078[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified078[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 9s 31ms/step - loss: 0.0198 - accuracy: 0.9956
# Accuracy: 99.562502%
# Loss: 1.976427%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified078.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.78) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified078 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified078)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 8s 31ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9925    0.9988    0.9956      4000
#     Positive     0.9987    0.9925    0.9956      4000
#
#     accuracy                         0.9956      8000
#    macro avg     0.9956    0.9956    0.9956      8000
# weighted avg     0.9956    0.9956    0.9956      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9956249572749735

# %% [markdown]
# # Modified MobileNet077 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified077 = MobileNet_Modified077.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified077[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified077[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 8s 29ms/step - loss: 0.0074 - accuracy: 0.9989
# Accuracy: 99.887502%
# Loss: 0.735266%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified077.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.77) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified077 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified077)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 8s 32ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9992    0.9985    0.9989      4000
#     Positive     0.9985    0.9992    0.9989      4000
#
#     accuracy                         0.9989      8000
#    macro avg     0.9989    0.9989    0.9989      8000
# weighted avg     0.9989    0.9989    0.9989      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9988749998417968

# %% [markdown]
# # Modified MobileNet076 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified076 = MobileNet_Modified076.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified076[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified076[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 8s 29ms/step - loss: 0.0129 - accuracy: 0.9980
# Accuracy: 99.800003%
# Loss: 1.287900%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified076.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.76) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified076 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified076)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 9s 33ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9985    0.9975    0.9980      4000
#     Positive     0.9975    0.9985    0.9980      4000
#
#     accuracy                         0.9980      8000
#    macro avg     0.9980    0.9980    0.9980      8000
# weighted avg     0.9980    0.9980    0.9980      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9979999994999998

# %% [markdown]
# # Modified MobileNet075 Model Validation

# %%
# evaluate model
print("==========================Evaluate Model====================")
scores_MobileNet_Modified075 = MobileNet_Modified075.evaluate(val_generator, verbose=1)
print("Accuracy: %.6f%%" % (scores_MobileNet_Modified075[1]*100))
print("Loss: %.6f%%" % (scores_MobileNet_Modified075[0]*100))
# Out:
# ==========================Evaluate Model====================
# 250/250 [==============================] - 8s 28ms/step - loss: 0.0079 - accuracy: 0.9976
# Accuracy: 99.762499%
# Loss: 0.793798%

# %%
# Confusion Matrix and Classification Report
target_names = ['Negative', 'Positive']
# Plot Confusion Matrix
print("==========================Confusion Matrix====================")
y_pred = MobileNet_Modified075.predict(val_generator)
y_pred = np.argmax(y_pred, axis=1)
cm = confusion_matrix(val_generator.classes, y_pred)
fig, ax = plot_confusion_matrix(conf_mat=cm ,  figsize=(5, 5))
ax.set_xticklabels([''] + target_names, rotation=45)
ax.set_yticklabels([''] + target_names, rotation=45)
plt.title('Confusion Matrix MobileNet MobileNet Modified (alpha=0.75) Model')
plt.show()

print("==========================Classification Report====================")
print('Classification Report')

print(classification_report(val_generator.classes, y_pred, target_names=target_names, digits=4))

# F1 Score
print("==========================F1 Score====================")
f1_MobileNet_Modified075 = f1_score(val_generator.classes, y_pred, average='weighted')
print('F1 Score : ', f1_MobileNet_Modified075)
# Out:
# ==========================Confusion Matrix====================
# 250/250 [==============================] - 8s 30ms/step
# ==========================Classification Report====================
# Classification Report
#               precision    recall  f1-score   support
#
#     Negative     0.9975    0.9978    0.9976      4000
#     Positive     0.9977    0.9975    0.9976      4000
#
#     accuracy                         0.9976      8000
#    macro avg     0.9976    0.9976    0.9976      8000
# weighted avg     0.9976    0.9976    0.9976      8000
#
# ==========================F1 Score====================
# F1 Score :  0.9976249999628906

# %% [markdown]
# # Wrap Up

# %%
# Make dictionary of all models
models = {'MobileNet_Basic': MobileNet_basic,
          "MobileNet_Modified099": MobileNet_Modified099,
          "MobileNet_Modified098": MobileNet_Modified098,
          "MobileNet_Modified097": MobileNet_Modified097,
          "MobileNet_Modified096": MobileNet_Modified096,
          "MobileNet_Modified095": MobileNet_Modified095,
          "MobileNet_Modified094": MobileNet_Modified094,
          "MobileNet_Modified093": MobileNet_Modified093,
          "MobileNet_Modified092": MobileNet_Modified092,
          "MobileNet_Modified091": MobileNet_Modified091,
          "MobileNet_Modified090": MobileNet_Modified090,
          "MobileNet_Modified089": MobileNet_Modified089,
          "MobileNet_Modified088": MobileNet_Modified088,
          "MobileNet_Modified087": MobileNet_Modified087,
          "MobileNet_Modified086": MobileNet_Modified086,
          "MobileNet_Modified085": MobileNet_Modified085,
          "MobileNet_Modified084": MobileNet_Modified084,
          "MobileNet_Modified083": MobileNet_Modified083,
          "MobileNet_Modified082": MobileNet_Modified082,
          "MobileNet_Modified081": MobileNet_Modified081,
          "MobileNet_Modified080": MobileNet_Modified080,
          "MobileNet_Modified079": MobileNet_Modified079,
          "MobileNet_Modified078": MobileNet_Modified078,
          "MobileNet_Modified077": MobileNet_Modified077,
          "MobileNet_Modified076": MobileNet_Modified076,
          "MobileNet_Modified075": MobileNet_Modified075
          }


# Make dictionary of all accuracy scores
scores = {'MobileNet_Basic': scores_MobileNet_Basic[1], 
          'MobileNet_Modified099': scores_MobileNet_Modified099[1],
          'MobileNet_Modified098': scores_MobileNet_Modified098[1],
          'MobileNet_Modified097': scores_MobileNet_Modified097[1],
          'MobileNet_Modified096': scores_MobileNet_Modified096[1],
          'MobileNet_Modified095': scores_MobileNet_Modified095[1],
          'MobileNet_Modified094': scores_MobileNet_Modified094[1],
          'MobileNet_Modified093': scores_MobileNet_Modified093[1],
          'MobileNet_Modified092': scores_MobileNet_Modified092[1],
          'MobileNet_Modified091': scores_MobileNet_Modified091[1],
          'MobileNet_Modified090': scores_MobileNet_Modified090[1],
          'MobileNet_Modified089': scores_MobileNet_Modified089[1],
          'MobileNet_Modified088': scores_MobileNet_Modified088[1],
          'MobileNet_Modified087': scores_MobileNet_Modified087[1],
          'MobileNet_Modified086': scores_MobileNet_Modified086[1],
          'MobileNet_Modified085': scores_MobileNet_Modified085[1],
          'MobileNet_Modified084': scores_MobileNet_Modified084[1],
          'MobileNet_Modified083': scores_MobileNet_Modified083[1],
          'MobileNet_Modified082': scores_MobileNet_Modified082[1],
          'MobileNet_Modified081': scores_MobileNet_Modified081[1],
          'MobileNet_Modified080': scores_MobileNet_Modified080[1],
          'MobileNet_Modified079': scores_MobileNet_Modified079[1],
          'MobileNet_Modified078': scores_MobileNet_Modified078[1],
          'MobileNet_Modified077': scores_MobileNet_Modified077[1],
          'MobileNet_Modified076': scores_MobileNet_Modified076[1],
          'MobileNet_Modified075': scores_MobileNet_Modified075[1]
          }

# Make dictionary of all loss scores
loss = {'MobileNet_Basic': scores_MobileNet_Basic[0], 
        'MobileNet_Modified099': scores_MobileNet_Modified099[0],
        'MobileNet_Modified098': scores_MobileNet_Modified098[0],
        'MobileNet_Modified097': scores_MobileNet_Modified097[0],
        'MobileNet_Modified096': scores_MobileNet_Modified096[0],
        'MobileNet_Modified095': scores_MobileNet_Modified095[0],
        'MobileNet_Modified094': scores_MobileNet_Modified094[0],
        'MobileNet_Modified093': scores_MobileNet_Modified093[0],
        'MobileNet_Modified092': scores_MobileNet_Modified092[0],
        'MobileNet_Modified091': scores_MobileNet_Modified091[0],
        'MobileNet_Modified090': scores_MobileNet_Modified090[0],
        'MobileNet_Modified089': scores_MobileNet_Modified089[0],
        'MobileNet_Modified088': scores_MobileNet_Modified088[0],
        'MobileNet_Modified087': scores_MobileNet_Modified087[0],
        'MobileNet_Modified086': scores_MobileNet_Modified086[0],
        'MobileNet_Modified085': scores_MobileNet_Modified085[0],
        'MobileNet_Modified084': scores_MobileNet_Modified084[0],
        'MobileNet_Modified083': scores_MobileNet_Modified083[0],
        'MobileNet_Modified082': scores_MobileNet_Modified082[0],
        'MobileNet_Modified081': scores_MobileNet_Modified081[0],
        'MobileNet_Modified080': scores_MobileNet_Modified080[0],
        'MobileNet_Modified079': scores_MobileNet_Modified079[0],
        'MobileNet_Modified078': scores_MobileNet_Modified078[0],
        'MobileNet_Modified077': scores_MobileNet_Modified077[0],
        'MobileNet_Modified076': scores_MobileNet_Modified076[0],
        'MobileNet_Modified075': scores_MobileNet_Modified075[0]
        }

# Make dictionary of all F1 scores
f1 = {'MobileNet_Basic': f1_MobileNet_basic, 
      'MobileNet_Modified099': f1_MobileNet_Modified099,
      'MobileNet_Modified098': f1_MobileNet_Modified098,
      'MobileNet_Modified097': f1_MobileNet_Modified097,
      'MobileNet_Modified096': f1_MobileNet_Modified096,
      'MobileNet_Modified095': f1_MobileNet_Modified095,
      'MobileNet_Modified094': f1_MobileNet_Modified094,
      'MobileNet_Modified093': f1_MobileNet_Modified093,
      'MobileNet_Modified092': f1_MobileNet_Modified092,
      'MobileNet_Modified091': f1_MobileNet_Modified091,
      'MobileNet_Modified090': f1_MobileNet_Modified090,
      'MobileNet_Modified089': f1_MobileNet_Modified089,
      'MobileNet_Modified088': f1_MobileNet_Modified088,
      'MobileNet_Modified087': f1_MobileNet_Modified087,
      'MobileNet_Modified086': f1_MobileNet_Modified086,
      'MobileNet_Modified085': f1_MobileNet_Modified085,
      'MobileNet_Modified084': f1_MobileNet_Modified084,
      'MobileNet_Modified083': f1_MobileNet_Modified083,
      'MobileNet_Modified082': f1_MobileNet_Modified082,
      'MobileNet_Modified081': f1_MobileNet_Modified081,
      'MobileNet_Modified080': f1_MobileNet_Modified080,
      'MobileNet_Modified079': f1_MobileNet_Modified079,
      'MobileNet_Modified078': f1_MobileNet_Modified078,
      'MobileNet_Modified077': f1_MobileNet_Modified077,
      'MobileNet_Modified076': f1_MobileNet_Modified076,
      'MobileNet_Modified075': f1_MobileNet_Modified075
      }

# Make dataframe of all models, accuracy, loss, and f1 score
df = pd.DataFrame(list(zip(models.keys(), scores.values(), loss.values(), f1.values())), 
               columns =['Model', 'Accuracy', 'Loss', 'F1 Score'])

# Sort dataframe by F1 Score
df.sort_values(by=['F1 Score'], inplace=True, ascending=False)

# Print dataframe
print(df)
# Out:
#                     Model  Accuracy      Loss  F1 Score
# 23  MobileNet_Modified077  0.998875  0.007353  0.998875
# 17  MobileNet_Modified083  0.998750  0.004388  0.998750
# 5   MobileNet_Modified095  0.998625  0.007763  0.998625
# 7   MobileNet_Modified093  0.998625  0.008669  0.998625
# 4   MobileNet_Modified096  0.998500  0.007670  0.998500
# 20  MobileNet_Modified080  0.998500  0.009321  0.998500
# 16  MobileNet_Modified084  0.998375  0.008585  0.998375
# 15  MobileNet_Modified085  0.998375  0.008358  0.998375
# 9   MobileNet_Modified091  0.998375  0.009726  0.998375
# 12  MobileNet_Modified088  0.998250  0.009395  0.998250
# 13  MobileNet_Modified087  0.998125  0.008268  0.998125
# 2   MobileNet_Modified098  0.998125  0.008217  0.998125
# 24  MobileNet_Modified076  0.998000  0.012879  0.998000
# 1   MobileNet_Modified099  0.998000  0.009118  0.998000
# 10  MobileNet_Modified090  0.998000  0.012234  0.998000
# 0         MobileNet_Basic  0.997875  0.011108  0.997875
# ...

# %%
# Export dataframe to csv
df.to_csv('MobileNet Model Performance.csv', index=False)
